# %% [markdown]
# <a href="https://colab.research.google.com/github/rgnemasters/coding-dojo-project-2/blob/main/Project2_Part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Assignment Header
# **Ryan Masters**
# *   Project 2 Part 1
# *   3/10/2022
# *   Week 7
# *   Disclosure: web-scraping method and code adapted from [DataQuest's 'Web Scraping NBA Stats With Python: Data Project [Part 1 of 3]](https://www.youtube.com/watch?v=JGQGd-oa0l4&t=1073s)

# %% [markdown]
# #First proposed dataset (with web-scraping steps)

# %% [markdown]
# ##Mount Data and Import Libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import requests

# %%
#Scrape combine data for 2000-2021 from Pro Football Reference
years = list(range(2000, 2022))

for year in years:
  data = requests.get(f'https://www.pro-football-reference.com/draft/{year}-combine.htm')
  with open('/content/drive/MyDrive/Project Notebooks/scraped pages/NFL_Combine_{}'.format(year), 'w+') as f:
    f.write(data.text)

# %% [markdown]
# ##Web scraping and DF prep

# %%
#Parse scraped pages and load to list
from bs4 import BeautifulSoup

combine_stats = []

for year in years:
  with open('/content/drive/MyDrive/Project Notebooks/scraped pages/NFL_Combine_{}'.format(year)) as f:
    page = f.read()
    soup = BeautifulSoup(page, 'html.parser')
    table = soup.find(id='combine')
    table_read = pd.read_html(str(table))[0]
    table_read['Year'] = year
    combine_stats.append(table_read)

# %%
#Concatanate list and review DF
combine_table = pd.concat(combine_stats)
report = pd.DataFrame({'columns': combine_table.columns,
                       'dtype': combine_table.dtypes,
                       'uniques': combine_table.nunique(),
                       'nulls': combine_table.isna().sum(),
                       '% nulls': combine_table.isna().sum()/len(combine_table)}).reset_index(drop=True)
display(report)
combine_table.head()
# Out:
#                 columns   dtype  uniques  nulls   % nulls
# 0                Player  object     7238      0  0.000000
# 1                   Pos  object       26      0  0.000000
# 2                School  object      325      0  0.000000
# 3               College  object        2   1415  0.188893
# 4                    Ht  object       20     29  0.003871
# 5                    Wt  object      208     24  0.003204
# 6                  40yd  object      160    385  0.051395
# 7              Vertical  object       59   1647  0.219864
# 8                 Bench  object       46   2333  0.311440
# 9            Broad Jump  object       64   1715  0.228941
# 10                3Cone  object      229   2656  0.354559
# 11              Shuttle  object      155   2562  0.342010
# 12  Drafted (tm/rnd/yr)  object     4704   2642  0.352690
# 13                 Year   int64       22      0  0.000000
#              Player  Pos          School        College   Ht   Wt  40yd  \
# 0      John Abraham  OLB  South Carolina            NaN  6-4  252  4.55
# 1   Shaun Alexander   RB         Alabama  College Stats  6-0  218  4.58
# 2    Darnell Alford   OT     Boston Col.            NaN  6-4  334  5.56
# 3      Kyle Allamon   TE      Texas Tech            NaN  6-2  253  4.97
# 4  Rashard Anderson   CB   Jackson State            NaN  6-2  206  4.55
#
#   Vertical Bench Broad Jump 3Cone Shuttle  \
# 0      NaN   NaN        NaN   NaN     NaN
# 1      NaN   NaN        NaN   NaN     NaN
# 2     25.0    23         94  8.48    4.98
# 3     29.0   NaN        104  7.29    4.49
# 4     34.0   NaN        123  7.18    4.15
#
#                             Drafted (tm/rnd/yr)  Year
# 0        New York Jets / 1st / 13th pick / 2000  2000
# 1     Seattle Seahawks / 1st / 19th pick / 2000  2000
# 2  Kansas City Chiefs / 6th / 188th pick / 2000  2000
# 3                                           NaN  2000
# 4    Carolina Panthers / 1st / 23rd pick / 2000  2000

# %%
#Drop 'College' column, as this functions just to house a hyperlink 
combine_table.drop(columns='College', inplace=True)

# %%
#Drop extra header rows 
combine_table.drop_duplicates(keep=False, inplace=True)
combine_table = combine_table.reset_index(drop=True)
combine_table.head(51)
# Out:
#                Player  Pos             School    Ht   Wt  40yd Vertical Bench  \
# 0        John Abraham  OLB     South Carolina   6-4  252  4.55      NaN   NaN
# 1     Shaun Alexander   RB            Alabama   6-0  218  4.58      NaN   NaN
# 2      Darnell Alford   OT        Boston Col.   6-4  334  5.56     25.0    23
# 3        Kyle Allamon   TE         Texas Tech   6-2  253  4.97     29.0   NaN
# 4    Rashard Anderson   CB      Jackson State   6-2  206  4.55     34.0   NaN
# 5         Jake Arians    K     Ala-Birmingham  5-10  202   NaN      NaN   NaN
# 6     LaVar Arrington  OLB         Penn State   6-3  250  4.53      NaN   NaN
# 7        Corey Atkins  OLB     South Carolina   6-0  237  4.72     31.0    21
# 8      Kyle Atteberry    K             Baylor   6-0  167   NaN      NaN   NaN
# 9       Reggie Austin   CB        Wake Forest   5-9  175  4.44     35.0    17
# 10         John Baker    P        North Texas   6-3  227   NaN      NaN   NaN
# 11     Mark Baniewicz   OT           Syracuse   6-6  312  5.34     28.0    20
# 12     Rashidi Barnes    S           Colorado   6-0  208  4.62     35.0    10
# 13      David Barrett   CB           Arkansas  5-10  199  4.44     37.5    16
# 14     William Bartee   CB           Oklahoma   6-1  192  4.43     38.5   NaN
# 15       Andrew Bayes    P      East Carolina   6-2  200   NaN      NaN   NaN
# 16   Terrance Beadles   OG     Ark-Pine Bluff   6-3  312  5.19      NaN    29
# 17        Robert Bean   CB  Mississippi State  5-11  178  4.50     34.5   NaN
# 18      Anthony Becht   TE      West Virginia   6-6  270  4.78     33.5   NaN
# 19          Matt Beck  ILB         California   6-3  234  4.65      NaN   NaN
# 20     Rogers Beckett    S           Marshall   6-1  207  4.62     39.5    15
# 21        Brad Bedell   OG           Colorado   6-4  302  5.07     31.5    17
# 22        Marcus Bell  ILB            Arizona   6-2  237  4.78     31.5    21
# 23         Gary Berry    S         Ohio State  5-11  204  4.55      NaN   NaN
# 24    Michael Boireau   DE         Miami (FL)   6-4  274  5.09     29.0    26
# 25         Matt Bowen    S               Iowa   6-1  201  4.49     33.0    12
# 26       Carl Bradley   DT      Virginia Tech   6-2  300  5.03      NaN   NaN
# 27          Tom Brady   QB           Michigan   6-4  211  5.28     24.5   NaN
# 28     Robert Brannon   DT         Iowa State   6-4  309  5.19     28.5    28
# 29        Keith Brown   RB               UCLA  5-11  216  4.66     30.0   NaN
# 30      Demario Brown   RB         Utah State   6-0  217  4.72     31.0   NaN
# 31     Courtney Brown   DE         Penn State   6-5  269  4.78      NaN   NaN
# 32         Mike Brown    S           Nebraska  5-10  204  4.59     36.0    14
# 33        Ralph Brown   CB           Nebraska  5-10  185  4.55      NaN    10
# 34       Travis Brown   QB   Northern Arizona   6-3  218  5.01     29.0   NaN
# 35      Lamont Bryant   DE         Notre Dame   6-3  260  4.91      NaN    17
# 36        Marc Bulger   QB      West Virginia   6-2  208  4.97      NaN   NaN
# 37      Keith Bulluck  OLB           Syracuse   6-3  244  4.47     38.0   NaN
# 38         Bill Burke   QB     Michigan State   6-4  206  5.03     28.5   NaN
# 39    Plaxico Burress   WR     Michigan State   6-5  231  4.59     33.0   NaN
# 40         David Byrd   CB           Syracuse  5-11  202  4.53     36.0    14
# 41     Trung Canidate   RB            Arizona  5-11  193  4.41      NaN    18
# 42    Cooper Carlisle   OG            Florida   6-5  297  5.16     31.0    28
# 43  Giovanni Carmazzi   QB            Hofstra   6-3  224  4.74     36.5   NaN
# 44    Leonardo Carson   DE             Auburn   6-1  283  5.06     28.0    22
# 45      Tyrone Carter    S          Minnesota   5-8  190  4.50     41.0    16
# 46        Kwame Cavil   WR              Texas   6-2  208  4.54     39.5   NaN
# 47    Chris Chaloupka   QB                SMU   6-2  216  4.96      NaN   NaN
# 48       Doug Chapman   RB           Marshall  5-10  215  4.56     38.5    16
# 49       Ike Charlton   CB      Virginia Tech  5-11  205  4.47      NaN    16
# 50     Chrys Chukwuma   RB           Arkansas   6-1  232  4.56      NaN   NaN
#
#    Broad Jump 3Cone Shuttle                             Drafted (tm/rnd/yr)  \
# 0         NaN   NaN     NaN          New York Jets / 1st / 13th pick / 2000
# 1         NaN   NaN     NaN       Seattle Seahawks / 1st / 19th pick / 2000
# 2          94  8.48    4.98    Kansas City Chiefs / 6th / 188th pick / 2000
# 3         104  7.29    4.49                                             NaN
# 4         123  7.18    4.15      Carolina Panthers / 1st / 23rd pick / 2000
# 5         NaN   NaN     NaN                                             NaN
# 6         NaN   NaN     NaN     Washington Redskins / 1st / 2nd pick / 2000
# 7         112  7.96    4.39                                             NaN
# 8         NaN   NaN     NaN                                             NaN
# 9         119  7.03    4.14         Chicago Bears / 4th / 125th pick / 2000
# 10        NaN   NaN     NaN                                             NaN
# 11         96  7.72    4.73  Jacksonville Jaguars / 7th / 247th pick / 2000
# 12        114  6.92    4.32      Cleveland Browns / 7th / 225th pick / 2000
# 13        116  6.81    4.04     Arizona Cardinals / 4th / 102nd pick / 2000
# 14        124  6.70    3.99     Kansas City Chiefs / 2nd / 54th pick / 2000
# 15        NaN   NaN     NaN                                             NaN
# 16        NaN   NaN     NaN                                             NaN
# 17        122  6.87    4.20    Cincinnati Bengals / 5th / 133rd pick / 2000
# 18        123  6.94    4.08          New York Jets / 1st / 27th pick / 2000
# 19        NaN   NaN     NaN                                             NaN
# 20        119  6.48    4.29     San Diego Chargers / 2nd / 43rd pick / 2000
# 21        103  7.76    4.58      Cleveland Browns / 6th / 206th pick / 2000
# 22        111  7.17    4.33      Seattle Seahawks / 4th / 116th pick / 2000
# 23        NaN   NaN     NaN     Green Bay Packers / 4th / 126th pick / 2000
# 24        105  7.68    4.49      Minnesota Vikings / 2nd / 56th pick / 2000
# 25        115  7.06    4.09        St. Louis Rams / 6th / 198th pick / 2000
# 26        NaN   NaN     NaN                                             NaN
# 27         99  7.20    4.38  New England Patriots / 6th / 199th pick / 2000
# 28         99  7.82    4.70                                             NaN
# 29        117  6.64    4.08                                             NaN
# 30        107  7.17    4.39                                             NaN
# 31        NaN   NaN     NaN        Cleveland Browns / 1st / 1st pick / 2000
# 32        116  6.93    4.01          Chicago Bears / 2nd / 39th pick / 2000
# 33        NaN   NaN     NaN       New York Giants / 5th / 140th pick / 2000
# 34        101  7.54    4.87                                             NaN
# 35        NaN   NaN     NaN                                             NaN
# 36        100  7.46    4.34    New Orleans Saints / 6th / 168th pick / 2000
# 37        119  7.33    4.13       Tennessee Titans / 1st / 30th pick / 2000
# 38        107  7.46    4.42                                             NaN
# 39        115   NaN     NaN     Pittsburgh Steelers / 1st / 8th pick / 2000
# 40        117  7.18    4.39                                             NaN
# 41        NaN   NaN     NaN         St. Louis Rams / 1st / 31st pick / 2000
# 42        100  7.82    4.48        Denver Broncos / 4th / 112th pick / 2000
# 43        119  6.94    4.23    San Francisco 49ers / 3rd / 65th pick / 2000
# 44        106  7.82    4.75    San Diego Chargers / 4th / 113th pick / 2000
# 45        121  6.75    4.19     Minnesota Vikings / 4th / 118th pick / 2000
# 46        118   NaN     NaN                                             NaN
# 47        NaN   NaN     NaN                                             NaN
# 48        128  6.84    4.20      Minnesota Vikings / 3rd / 88th pick / 2000
# 49        126   NaN     NaN       Seattle Seahawks / 2nd / 52nd pick / 2000
# 50        115   NaN     NaN                                             NaN
#
#     Year
# 0   2000
# 1   2000
# 2   2000
# 3   2000
# 4   2000
# 5   2000
# 6   2000
# 7   2000
# 8   2000
# 9   2000
# 10  2000
# 11  2000
# 12  2000
# 13  2000
# 14  2000
# 15  2000
# 16  2000
# 17  2000
# 18  2000
# 19  2000
# 20  2000
# 21  2000
# 22  2000
# 23  2000
# 24  2000
# 25  2000
# 26  2000
# 27  2000
# 28  2000
# 29  2000
# 30  2000
# 31  2000
# 32  2000
# 33  2000
# 34  2000
# 35  2000
# 36  2000
# 37  2000
# 38  2000
# 39  2000
# 40  2000
# 41  2000
# 42  2000
# 43  2000
# 44  2000
# 45  2000
# 46  2000
# 47  2000
# 48  2000
# 49  2000
# 50  2000

# %%
#Convert numeric values to 'float' values
#Waiting to convert 'Ht', since this will require changing the data format
combine_table[['Wt', '40yd', 'Vertical',
       'Bench', 'Broad Jump', '3Cone', 'Shuttle']]=combine_table[['Wt', '40yd', 'Vertical',
       'Bench', 'Broad Jump', '3Cone', 'Shuttle']].astype(float)

report
# Out:
#                 columns   dtype  uniques  nulls   % nulls
# 0                Player  object     7238      0  0.000000
# 1                   Pos  object       26      0  0.000000
# 2                School  object      325      0  0.000000
# 3               College  object        2   1415  0.188893
# 4                    Ht  object       20     29  0.003871
# 5                    Wt  object      208     24  0.003204
# 6                  40yd  object      160    385  0.051395
# 7              Vertical  object       59   1647  0.219864
# 8                 Bench  object       46   2333  0.311440
# 9            Broad Jump  object       64   1715  0.228941
# 10                3Cone  object      229   2656  0.354559
# 11              Shuttle  object      155   2562  0.342010
# 12  Drafted (tm/rnd/yr)  object     4704   2642  0.352690
# 13                 Year   int64       22      0  0.000000

# %%
combine_table.to_csv(path_or_buf='/content/drive/MyDrive/Project Notebooks/scraped pages/Combine_2000_2020.csv')

# %% [markdown]
# ##Answers to Assignment Questions, DF header for First Choice

# %%
print(combine_table.shape)
print(combine_table.info())
combine_table.head()
# Out:
# (7356, 13)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7356 entries, 0 to 7355
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Player               7356 non-null   object
#  1   Pos                  7356 non-null   object
#  2   School               7356 non-null   object
#  3   Ht                   7327 non-null   object
#  4   Wt                   7332 non-null   float64
#  5   40yd                 6971 non-null   float64
#  6   Vertical             5709 non-null   float64
#  7   Bench                5023 non-null   float64
#  8   Broad Jump           5641 non-null   float64
#  9   3Cone                4700 non-null   float64
#  10  Shuttle              4794 non-null   float64
#  11  Drafted (tm/rnd/yr)  4714 non-null   object
#  12  Year                 7356 non-null   int64
# dtypes: float64(7), int64(1), object(5)
# memory usage: 747.2+ KB
# None
#              Player  Pos          School   Ht     Wt  40yd  Vertical  Bench  \
# 0      John Abraham  OLB  South Carolina  6-4  252.0  4.55       NaN    NaN
# 1   Shaun Alexander   RB         Alabama  6-0  218.0  4.58       NaN    NaN
# 2    Darnell Alford   OT     Boston Col.  6-4  334.0  5.56      25.0   23.0
# 3      Kyle Allamon   TE      Texas Tech  6-2  253.0  4.97      29.0    NaN
# 4  Rashard Anderson   CB   Jackson State  6-2  206.0  4.55      34.0    NaN
#
#    Broad Jump  3Cone  Shuttle                           Drafted (tm/rnd/yr)  \
# 0         NaN    NaN      NaN        New York Jets / 1st / 13th pick / 2000
# 1         NaN    NaN      NaN     Seattle Seahawks / 1st / 19th pick / 2000
# 2        94.0   8.48     4.98  Kansas City Chiefs / 6th / 188th pick / 2000
# 3       104.0   7.29     4.49                                           NaN
# 4       123.0   7.18     4.15    Carolina Panthers / 1st / 23rd pick / 2000
#
#    Year
# 0  2000
# 1  2000
# 2  2000
# 3  2000
# 4  2000

# %% [markdown]
# 1) Source of data
#
#
# **This is NFL Combine data from 2000-2021. This data was scraped from Pro Football Reference.**
#
#
#
#
# 2) Brief description of data
#
# **This data includes various metrics gathered from the NFL Combine**
#
# 3) What is the target?
#
# **The target will be draft round. Currently the Draft column of data is in string format, but I plan to convert this either to an overall draft position or a round**
#
# 4) Is this a classification or regression problem?
#
# **If I choose to just use the draft round as a target, than this is a multi-class classification problem. If I use overall draft placement, this will be a regression problem.**
#
# 5) How many features?
#
# **13, though I may drop 1 or 2**
#
# 6) How many rows of data.
#
# **7,356**
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?
#
# **This dataset is full of null values, since players participate (or don't) in different drills based on position. I will have to decide what imputation might be best, especially with the high % null columns. I'll also need to transform the 'Drafted' and 'Ht' columns, which may be tricky**

# %% [markdown]
# #Second proposed dataset

# %%
filename = '/content/drive/MyDrive/Project Notebooks/Datasets for personal projects/Team_Stat_Table_Main.csv'
df = pd.read_csv(filename)
df = df.drop(columns='Unnamed: 0')
print(df.shape)
print(df.info())
df.head()
# Out:
# (1164, 27)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1164 entries, 0 to 1163
# Data columns (total 27 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rk            1164 non-null   float64
#  1   Team          1164 non-null   object
#  2   G             1164 non-null   int64
#  3   MP            1164 non-null   int64
#  4   FG            1164 non-null   int64
#  5   FGA           1164 non-null   int64
#  6   FG%           1164 non-null   float64
#  7   3P            1164 non-null   float64
#  8   3PA           1164 non-null   float64
#  9   3P%           1164 non-null   float64
#  10  2P            1164 non-null   int64
#  11  2PA           1164 non-null   int64
#  12  2P%           1164 non-null   float64
#  13  FT            1164 non-null   int64
#  14  FTA           1164 non-null   int64
#  15  FT%           1164 non-null   float64
#  16  ORB           1164 non-null   int64
#  17  DRB           1164 non-null   int64
#  18  TRB           1164 non-null   int64
#  19  AST           1164 non-null   int64
#  20  STL           1164 non-null   int64
#  21  BLK           1164 non-null   int64
#  22  TOV           1164 non-null   int64
#  23  PF            1164 non-null   int64
#  24  PTS           1164 non-null   int64
#  25  Season        1164 non-null   int64
#  26  playoff_team  1164 non-null   bool
# dtypes: bool(1), float64(7), int64(18), object(1)
# memory usage: 237.7+ KB
# None
#     Rk                 Team   G     MP    FG   FGA    FG%     3P    3PA  \
# 0  1.0    San Antonio Spurs  82  19755  3856  7738  0.498   52.0  206.0
# 1  2.0   Los Angeles Lakers  82  19880  3898  7368  0.529   20.0  100.0
# 2  3.0  Cleveland Cavaliers  82  19930  3811  8041  0.474   36.0  187.0
# 3  4.0      New York Knicks  82  19780  3802  7672  0.496   42.0  191.0
# 4  5.0       Boston Celtics  82  19880  3617  7387  0.490  162.0  422.0
#
#      3P%  ...   DRB   TRB   AST  STL  BLK   TOV    PF   PTS  Season  \
# 0  0.252  ...  2515  3668  2326  771  333  1589  2103  9788    1980
# 1  0.200  ...  2653  3738  2413  774  546  1639  1784  9438    1980
# 2  0.193  ...  2381  3688  2108  764  342  1370  1934  9360    1980
# 3  0.220  ...  2303  3539  2265  881  457  1613  2168  9344    1980
# 4  0.384  ...  2457  3684  2198  809  308  1539  1974  9303    1980
#
#    playoff_team
# 0          True
# 1          True
# 2         False
# 3         False
# 4          True
#
# [5 rows x 27 columns]

# %% [markdown]
# ##Answers to Assignment Questions, DF header for Second Choice

# %% [markdown]
# 1) Source of data
#
# **I scraped this data from [Basketball Reference](https://www.basketball-reference.com/)**.
#
# 2) Brief description of data
#
# **This is overall team stats for every season since the introduction of the 3-pt line in 1980**
#
# 3) What is the target?
#
# **The target is 'playoff_team,' which is a binary (boolean) category. The point will be to predict this season's playoff teams**
#
# 4) Is this a classification or regression problem?
#
# **This is a binary classification problem.**
#
# 5) How many features?
#
# **This dataset has 27 features**
#
# 6) How many rows of data.
#
# **This dataset has 1164 rows**
#
# 7) What, if any, challenges do your foresee in cleaning, exploring, or modeling with this dataset?
#
# **This dataset is pretty straight-forward. The only thing that might be tricky in modelling is working with 27 features, which is more than I have ever worked with so far**
